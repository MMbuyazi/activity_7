# %%
import pandas as pd
#import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:/Users/cash/Downloads/dataset - 2020-09-24 (1).csv")

# %%
print(df.duplicated().sum())
0
# Out:
# 0
# 0

# %%
plt.scatter(df['Wins'],df['Losses'])
plt.title('Scatter plot for wins vs. losses')
plt.xlabel('Wins')
plt.ylabel('Losses')
plt.show()

# %%
data =np.random.normal(loc=20.0,scale=5.0,size= 365)
plt.hist(data,bins=20,color= 'blue',alpha=0.7)
plt.title('Histogram for Wins vs. Losses')
plt.xlabel('Wins')
plt.ylabel('Loses')
plt.show()

# %%
plt.figure(figsize= (8,5))
plt.bar(Wins, Losses, color ='blue', alpha=0.7)
plt.title('Bar chart for Wins vs Losses')
plt.xlabel('Wins')
plt.ylabel('Losses')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 plt.figure(figsize= (8,5))
# ----> 2 plt.bar(Wins, Losses, color ='blue', alpha=0.7)
#       3 plt.title('Bar chart for Wins vs Losses')
#       4 plt.xlabel('Wins')
#
# NameError: name 'Wins' is not defined

# %%
plt.figure(figsize=(7,8))
plt.pie(Wins, labels=Name,autopct='%1.1f%%',startangle=140)
plt.title('Pie chart for Football share')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 3
#       1 #Nationality =['England','Bosnia And Herzegovina','France','Spain']
#       2 plt.figure(figsize=(7,8))
# ----> 3 plt.pie(Wins, labels=Name,autopct='%1.1f%%',startangle=140)
#       4 plt.title('Pie chart for Football share')
#       5 plt.show()
#
# NameError: name 'Wins' is not defined

# %%
plt.figure(figsize= (8,5))
plt.bar(Position, Jersey_Number, color ='blue', alpha=0.7)
plt.title('Bar chart for Wins vs Losses')
plt.xlabel('Position')
plt.ylabel('Jersey_Number')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 plt.figure(figsize= (8,5))
# ----> 2 plt.bar(Position, Jersey_Number, color ='blue', alpha=0.7)
#       3 plt.title('Bar chart for Wins vs Losses')
#       4 plt.xlabel('Position')
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:2754, in bar(x, height, width, bottom, align, data, **kwargs)
#    2743 @_copy_docstring_and_deprecators(Axes.bar)
#    2744 def bar(
#    2745     x: float | ArrayLike,
#    (...)
#    2752     **kwargs,
#    2753 ) -> BarContainer:
# -> 2754     return gca().bar(
#    2755         x,
#    2756         height,
#    2757         width=width,
#    2758         bottom=bottom,
#    2759         align=align,
#    2760         **({"data": data} if data is not None else {}),
#    2761         **kwargs,
#    2762     )
#
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv(r"C:/Users/cash/Downloads/dataset - 2020-09-24 (1).csv")

plt.scatter(df['Jersey_Number'],df['Position'])
plt.title('Scatter plot for Jersey_Number vs. Positions')
plt.xlabel('Jersey_Number')
plt.ylabel('Position')
plt.show()

# %%
import numpy as np

data =np.random.normal(loc=20.0,scale=5.0,size= 365)
plt.hist(data,bins=20,color= 'blue',alpha=0.7)
plt.title('Histogram for Jersey_Number vs. Position')
plt.xlabel('Jersey_Number')
plt.ylabel('Position')
plt.show()

# %%
#Position = ['Goalkeeper'],['Defender'],['Midfilelder'],['Forwad']
#Jersey_Number = [1, 31, 10, 19]
plt.figure(figsize=(7,7))
plt.pie(Jersey_Number, labels= Position,autopct='%1.1f%%',startangle=140)
plt.title('Pie chart for Football share')
plt.show()
